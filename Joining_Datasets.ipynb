# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)

# visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
import plotly.figure_factory as ff
import calmap

# %%
df1 = pd.read_excel('HR_employeesurvey_may2020.xlsx', index_col=0, header=0, sheet_name='F_EmployeeSurvey')

# %%
df2 = pd.read_excel('HR_employeesurvey_may2020.xlsx', index_col=0, header=0, sheet_name='D_MaritalStatus')

# %%
df3 = pd.read_excel('HR_employeesurvey_may2020.xlsx', index_col=0, header=0, sheet_name='D_Gender')

# %%
df4 = pd.read_excel('HR_employeesurvey_may2020.xlsx', index_col=0, header=0, sheet_name='D_Education')

# %%
df5 = pd.read_excel('HR_employeesurvey_may2020.xlsx', index_col=0, header=0, sheet_name='D_Department')

# %%
df6 = pd.read_excel('HR_employeesurvey_may2020.xlsx', index_col=0, header=0, sheet_name='D_JobRole')

# %%
df7 = pd.read_excel('HR_employeesurvey_may2020.xlsx', index_col=0, header=0, sheet_name='F_employeeSalaries')

# %%
df=pd.merge(df1, df6, on='JobRoleId', how="left")
df.head()
# Out:
#    DepartmentId  EducationId  GenderId  Age  JobLevel  JobRoleId  \
# 0             2            2         2   41         2          6
# 1             1            1         1   49         2          3
# 2             1            2         1   37         1          2
# 3             1            4         2   33         1          3
# 4             1            1         1   27         1          2
#
#    MartialStatusId  YearofHire DateofHire                JobRole
# 0                1        2014   1/1/2014        Sales Executive
# 1                2        2010   1/1/2010     Research Scientist
# 2                1        2020   1/1/2020  Laboratory Technician
# 3                2        2012   1/1/2012     Research Scientist
# 4                2        2018   1/1/2018  Laboratory Technician

# %%
df01=pd.merge(df, df2, on='MartialStatusId', how="left")
df01.head()
# Out:
#    DepartmentId  EducationId  GenderId  Age  JobLevel  JobRoleId  \
# 0             2            2         2   41         2          6
# 1             1            1         1   49         2          3
# 2             1            2         1   37         1          2
# 3             1            4         2   33         1          3
# 4             1            1         1   27         1          2
#
#    MartialStatusId  YearofHire DateofHire                JobRole MartialStatus
# 0                1        2014   1/1/2014        Sales Executive        Single
# 1                2        2010   1/1/2010     Research Scientist       Married
# 2                1        2020   1/1/2020  Laboratory Technician        Single
# 3                2        2012   1/1/2012     Research Scientist       Married
# 4                2        2018   1/1/2018  Laboratory Technician       Married

# %%
df02=pd.merge(df01, df3, on='GenderId', how="left")
df02.head()
# Out:
#    DepartmentId  EducationId  GenderId  Age  JobLevel  JobRoleId  \
# 0             2            2         2   41         2          6
# 1             1            1         1   49         2          3
# 2             1            2         1   37         1          2
# 3             1            4         2   33         1          3
# 4             1            1         1   27         1          2
#
#    MartialStatusId  YearofHire DateofHire                JobRole  \
# 0                1        2014   1/1/2014        Sales Executive
# 1                2        2010   1/1/2010     Research Scientist
# 2                1        2020   1/1/2020  Laboratory Technician
# 3                2        2012   1/1/2012     Research Scientist
# 4                2        2018   1/1/2018  Laboratory Technician
#
#   MartialStatus  Gender
# 0        Single  Female
# 1       Married    Male
# 2        Single    Male
# 3       Married  Female
# 4       Married    Male

# %%
df03=pd.merge(df02, df4, on='EducationId', how="left")
df03.head()
# Out:
#    DepartmentId  EducationId  GenderId  Age  JobLevel  JobRoleId  \
# 0             2            2         2   41         2          6
# 1             1            1         1   49         2          3
# 2             1            2         1   37         1          2
# 3             1            4         2   33         1          3
# 4             1            1         1   27         1          2
#
#    MartialStatusId  YearofHire DateofHire                JobRole  \
# 0                1        2014   1/1/2014        Sales Executive
# 1                2        2010   1/1/2010     Research Scientist
# 2                1        2020   1/1/2020  Laboratory Technician
# 3                2        2012   1/1/2012     Research Scientist
# 4                2        2018   1/1/2018  Laboratory Technician
#
#   MartialStatus  Gender        Education
# 0        Single  Female          College
# 1       Married    Male      High School
# 2        Single    Male          College
# ...

# %%
df04=pd.merge(df03, df5, on='DepartmentId', how="left")
df04
# Out:
#       DepartmentId  EducationId  GenderId  Age  JobLevel  JobRoleId  \
# 0                2            2         2   41         2          6
# 1                1            1         1   49         2          3
# 2                1            2         1   37         1          2
# 3                1            4         2   33         1          3
# 4                1            1         1   27         1          2
# 5                1            2         1   32         1          2
# 6                1            3         2   59         1          2
# 7                1            1         1   30         1          2
# 8                1            3         1   38         3          5
# 9                1            3         1   36         2          1
# 10               1            3         1   35         1          2
# 11               1            2         2   29         2          2
# 12               1            1         1   31         1          3
# ...
